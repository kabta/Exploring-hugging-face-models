# %% [markdown]
# <a href="https://colab.research.google.com/github/kabta/Exploring-hugging-face-models/blob/main/huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question Answering
#
# * Easy to run with standard tools
# * Models default to English
# * But you can find many more at the HuggingFace model repository

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 31.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 28.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 10.6 MB/s eta 0:00:00
# ...

# %%
import transformers
#this will load a default English model trained for Question Answering
pipe=transformers.pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
context="""Forbes has ranked Finland as the world's sixth best country for business in its annual list,
the Best Countries for Business. Finland is the best country in the world in terms of individual and property rights, 
the  second best in terms of the innovation landscape and 
the third best in terms of corruption, the American business magazine lists."""

pipe(question="What is Finland's rank in terms of innovation?", context=context)
# Out:
# {'score': 0.4382377862930298, 'start': 217, 'end': 223, 'answer': 'second'}

# %% [markdown]
# # Question Answering tasks
#
# ## Task 1
#
# * Pick a few short paragraphs from your favorite source
# * Come up with a few questions with an answer in the text and test the QA model
# * How well did the model fare?
# * Was it easy to come up with non-trivial questions? Think whether this approach is a good approach to build a QA dataset.
#
# ## Task 2
#
# * If you can access ChatGPT, ask it the same questions. Did it succeed?
#
# ## Task 3
#
# * Explore the Hugging Face model repository. https://huggingface.co/models
# * Try some of the QA models for a language of your interest. Can you find any? Below you can see a model for Finnish.

# %% [markdown]
# ## TASK 1

# %%
pipe=transformers.pipeline("question-answering",model="TurkuNLP/bert-base-finnish-cased-squad2")

# %%
context="""Mount Everest, Sanskrit and Nepali Sagarmatha, Tibetan Chomolungma, Chinese (Pinyin) Zhumulangma Feng or (Wade-Giles romanization) Chu-mu-lang-ma Feng, also spelled Qomolangma Feng, mountain on the crest of the Great Himalayas of southern Asia that lies on the border between Nepal and the Tibet Autonomous Region of China, at 27°59′ N 86°56′ E. Reaching an elevation of 29,032 feet (8,849 metres), Mount Everest is the highest mountain in the world.
Mount Everst lies in Nepal"""
pipe(question="Which is th heighest peak in the world?", context=context)
# Out:
# {'score': 0.002409803681075573,
#  'start': 399,
#  'end': 412,
#  'answer': 'Mount Everest'}

# %%
pipe(question="Where does Mount everst lie?", context=context)
# Out:
# {'score': 0.08087880909442902, 'start': 472, 'end': 477, 'answer': 'Nepal'}

# %% [markdown]
# ## Task 2
# ChatGPT also gave the same answer

# %% [markdown]
# ## Task 3
# From Hugging face model repsitory, I looked for qa Nepali language model, couldnot find one, so I tried German model, and it worked fine for the question I asked as shown below.

# %%
pipe=transformers.pipeline("question-answering",model="deepset/gelectra-base-germanquad")

# %%
context="""Mount Everest, Sanskrit und Nepalesisch Sagarmatha, tibetisch Chomolungma, chinesisch (Pinyin) Zhumulangma Feng oder (Wade-Giles Romanisierung) Chu-mu-lang-ma Feng, auch Qomolangma Feng geschrieben, Berg auf dem Kamm des Großen Himalaya in Südasien liegt an der Grenze zwischen Nepal und der Autonomen Region Tibet in China, bei 27°59′ N 86°56′ O. Der Mount Everest ist mit einer Höhe von 29.032 Fuß (8.849 Meter) der höchste Berg der Welt.
Der Mount Everst liegt in Nepal. """
pipe(question="Wo liegt der Mount Everst?", context=context)
# Out:
# {'score': 0.7817428112030029, 'start': 464, 'end': 472, 'answer': 'in Nepal'}

# %% [markdown]
# # Summarization
#
# * text2text problem
#
# ## Task 1
#
# * Pick a text of your liking, and test the summarization pipeline below on it. Does it do a decent job?
#
# ## Task 2
#
# * The pipeline accepts a `min_length` and `max_length` parameters when you run it, try to adjust these to various lengths and see if the model comes up with a reasonable summarization choice.
#
# ## Task 3
#
# * Explore the Hugging Face models repository and experiment with summarization models for other languages of your choice. Do they exist? Do they work?
#
# ## Task 4
#
# * If you can access ChatGPT, try to have it summarize a piece of text. Did it work as you expected? Were you able to control the length effectively? How about other languages?

# %% [markdown]
# ## Task 1 and Task 2

# %%
pipe=transformers.pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
context="""
Mount Everest, also known as Sagarmatha in Nepal and Chomolungma in Tibet, is located in the Himalayas on the border between Nepal and Tibet (which is currently administered by China). 
The coordinates of Mount Everest are approximately 27.9881° N latitude and 86.9253° E longitude. It is the highest mountain in the world, with an elevation of 8,848.86 meters (29,031.69 feet) above sea level.
It has an elevation of 8,848.86 meters (29,031.69 feet) above sea level. It was first summited by Sir Edmund Hillary of New Zealand and Tenzing Norgay, a Sherpa of Nepal, in 1953.
"""

pipe(context)
#Note: you can do this: 
#pipe(context,min_length=15,max_length=30)
# Out:
# [{'summary_text': ' Mount Everest, also known as Sagarmatha in Nepal and Chomolungma in Tibet, is located in the Himalayas on the border between Nepal and Tibet . It is the highest mountain in the world, with an elevation of 8,848.86 meters (29,031.69 feet) above sea level .'}]

# %% [markdown]
# ## Task 3
# I looked for Nepali Hugging face summarization model, but they didnot exist. Then I tried searching for German one, I found some. I used one of them below. And it worked fine.

# %%
pipe=transformers.pipeline("summarization",model="Shahm/bart-german")

# %%
context=""" Der Mount Everest, in Nepal auch als Sagarmatha und in Tibet als Chomolungma bekannt, liegt im Himalaya an der Grenze zwischen Nepal und Tibet (das derzeit von China verwaltet wird).
Die Koordinaten des Mount Everest sind ungefähr 27,9881° nördlicher Breite und 86,9253° östlicher Länge. Es ist der höchste Berg der Welt mit einer Höhe von 8.848,86 Metern (29.031,69 Fuß) über dem Meeresspiegel.
Es hat eine Höhe von 8.848,86 Metern (29.031,69 Fuß) über dem Meeresspiegel. Er wurde erstmals 1953 von Sir Edmund Hillary aus Neuseeland und Tenzing Norgay, einem Sherpa aus Nepal, bestiegen. """
pipe(context)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1186: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# [{'summary_text': 'Die Koordinaten des Mount Everest sind ungefähr 27,9881° nördlicher Breite und 86,9253° östlicher Länge.'}]

# %% [markdown]
# ## Task 4
# Using ChatGPT, I couldnot control the length of the summarized text. It gave me longer summary. It gave me longer summary for German Text also.
